# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
xs = np.linspace(0, 10, 100)
xs
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
epsilons = np.random.standard_normal(100)
epsilons[5:]
# Out:
# array([-1.00478084e+00,  1.66469498e-01, -2.11117636e+00, -1.16430133e+00,
#         4.89101933e-01,  9.00556871e-01, -9.33438429e-01,  4.51951996e-01,
#         7.10675630e-01,  8.15224378e-01, -3.95909523e-01, -4.67883125e-01,
#        -3.93829035e-01,  1.13254957e-01, -1.31974392e+00, -1.09502142e+00,
#        -6.62237629e-01,  4.65365420e-02,  1.20134756e+00,  3.01241800e-01,
#         3.42028083e-01,  1.66574285e-01,  4.07570944e-01,  8.46951723e-01,
#         1.79875033e-01, -4.20309341e-01,  9.37253306e-02, -7.98810108e-01,
#        -3.40737890e-01, -1.67012983e-01,  2.95869712e-01,  1.27219850e+00,
#         2.11190627e+00, -1.16623348e+00, -2.02651506e+00, -2.05182340e+00,
#        -1.14531142e+00,  1.29105685e+00,  1.92926139e-03,  1.35552847e+00,
#         1.39673160e+00, -7.66663016e-01, -8.25718373e-02,  1.91718872e-01,
#         7.00189538e-01,  3.52272376e-01,  7.98612169e-01, -4.54853822e-01,
# ...

# %%
ys = 2*xs + 4 + epsilons
ys
# Out:
# array([ 3.98443979,  4.25002993,  3.64486944,  3.41441447,  5.39876397,
#         4.00532017,  5.37859071,  3.30296505,  4.45186029,  6.30728375,
#         6.92075889,  5.28878379,  6.87619442,  7.33693826,  7.64350721,
#         6.63439351,  6.76444011,  7.0405144 ,  7.74961859,  6.51863992,
#         6.94538262,  7.58018661,  8.49098099,  9.8478122 ,  9.14972665,
#         9.39253313,  9.41909954,  9.8621164 , 10.50351738, 10.03846089,
#         9.64029672, 10.35635159,  9.66583636, 10.32592878, 10.70167389,
#        11.36657678, 12.54492577, 13.58665375, 10.51053419,  9.85227282,
#        10.02898468, 11.13751686, 13.77590534, 12.68879795, 14.24441736,
#        14.48764069, 12.52626628, 13.41237766, 13.88868857, 14.59917944,
#        14.45328248, 15.10164247, 14.05019668, 13.21660197, 14.79086187,
#        13.81158096, 15.68384546, 15.20626753, 16.28492943, 16.81231342,
#        14.74517122, 16.31274419, 16.62624747, 15.89959222, 17.70496918,
# ...

# %%
plt.plot(xs, ys)

# %%
xs.shape, ys.shape
# Out:
# ((100,), (100,))

# %%
xs = xs.reshape(-1,1)

# %%
np.zeros((5, 1))
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
X_train, X_test, y_train, y_test = xs[:70], xs[70:], ys[:70], ys[70:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((70, 1), (30, 1), (70,), (30,))

# %%
from lin_reg_class import LinReg 

model = LinReg()
w, b, l = model.fit(X_train, y_train)
predictions = model.predict(xs)

# %%
# Plotting our predictions.
fig = plt.figure(figsize=(8, 6))
plt.scatter(xs, ys)
plt.plot(xs, predictions)  # X and predictions.
plt.title('Hours vs Percentage')
plt.xlabel('X (Input) : Hours')
plt.ylabel('y (Target) : Scores')
# Out:
# Text(0, 0.5, 'y (Target) : Scores')

# %%
X_test_preds = model.predict(X_test)
X_test_preds[:5]
# Out:
# array([[18.23467104],
#        [18.44453613],
#        [18.65440121],
#        [18.8642663 ],
#        [19.07413139]])

# %%
y_test.shape, X_test_preds.shape
# Out:
# ((30,), (30, 1))

# %%
X_test_preds = np.ndarray.flatten(X_test_preds)

# %%
df = pd.DataFrame({"Actual": y_test, "Predicted": X_test_preds})
df.head(5)
# Out:
#       Actual  Predicted
# 0  16.345336  18.234671
# 1  17.055622  18.444536
# 2  17.934566  18.654401
# 3  18.597275  18.864266
# 4  18.623246  19.074131

# %%
xs = np.linspace(0, 100, 10)
m = xs.shape[0]
m
# Out:
# 10

# %%
from itertools import combinations

combs = combinations(range(1, 4), 2)
combs_list = list(combs)
combs_list
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
import numpy as np

rand_int = np.random.randint(0, 3)
rand_int
# Out:
# 2

# %%
combs_list[rand_int]
# Out:
# (2, 3)

# %%
zeros = np.zeros((5,1))
zeros += 1
zeros
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
W = np.array([1.0, 2.5, -3.3])
b = 4
X = np.array([10, 20, 20])

# %%
W @ X.T + b
# Out:
# -2.0

# %%
f = 0

for i in range(len(W)):
    f += W[i] * X[i]
f = f + b
f
# Out:
# -2.0

# %%
f = np.dot(W, X) + b
f
# Out:
# -2.0
